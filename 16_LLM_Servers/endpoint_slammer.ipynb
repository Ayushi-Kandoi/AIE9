# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/ayushikandoi24-5198c/deployments/rgrwmom8"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x122fbb750>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x122fba210>
# **Answer:**
#
# It’s a tongue‑twister that’s been floating around for generations, and nobody has ever measured a wood‑chuck that’s actually eager to throw lumber.  If a wood‑chuck *were* an eager wood‑chucker, the estimate that usually pops up is **about 700 pounds of wood per day**—just enough to clear a little “twister‑forest” beside its burrow.  In practical terms, a single wood‑chuck that can actually chuck wood would probably only manage a single boulder‑sized chunk at a time—roughly the size of a small barnet or a pineapple‑wide log (on the order of 1–2 feet in diameter and 4–5 feet long).
#
# Why 700 pounds?
# - **Scale of the animal**: A typical wood‑chuck weighs ~20–30 lb.
# - **Work‐capacity**: At a gentle 10 lb of wood per minute (a generous estimate for a quick “chuck”), one wood‑chuck could move ~60 lb in an hour, roughly a ton in eight hours.  Adjusting for realistic fatigue and the fact that “chucking” is not a sustained activity, we get to the 700‑lb figure.
#
# Keep in mind:
# - Wood‑chucks (aka groundhogs) are burrowing mammals, not lumberjacks.
# - They’re more interested in digging than throwing.
# - The numbers above are, frankly, *just for fun*—they’re tongue‑twister folklore, not hard science.
#
# Bottom line: **If a wood‑chuck could chuck wood, it could chuck roughly the equivalent of a small log or a 700‑lb pile of pine pieces over the course of a workday—just enough to give its burrow a new “wood‑chuck” name tag.**

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 11: About **700 pounds**—that’s the classic estimate for a woodc...
# Response 8: A classic estimate (Richard Thomas, 1988) puts a woodchuck’s...
# Response 7: A classic tongue‑twister, but even the best of woodchucks (a...
# Response 17: A wood‑chuck would probably chuck about **700 pounds of wood...
# Response 13: A woodchuck could chuck approximately 7,000 boards in a day—...
# Response 2: **Request 2**
#
# The classic tongue‑twister doesn’t have a def...
# Response 22: Not a precise science question, but the classic answer goes:...
# Response 23: It’s a classic tongue‑twister, and the answer is as playful ...
# Response 24: In short—about **700 pounds** of wood a day.
#
# That’s the c...
# Response 3: The classic tongue‑twister itself is a bit of folklore: it d...
# Response 10: Sure! A classic estimate suggests that a woodchuck could chu...
# Response 6: A classic tongue‑twister, but if we treat it seriously for a...
# Response 18: Ah, the age‑old riddle that tickles tongues and tickles tree...
# Response 21: If a woodchuck could chuck wood, it would probably chuck abo...
# Response 9: **Answer (in the spirit of the classic tongue‑twister):**
#
# >...
# Response 4: If a wood‑chuck could actually chuck wood, the tongue‑twiste...
# Response 19: That infamous line is really just a tongue‑twister—there’s n...
# Response 15: **Answer – the classic tongue‑twister version**
#
# > *"A woodc...
# Response 1: **The classic answer**
# > “A wood‑chuck would chuck as much...
# Response 14: Ah, the classic tongue‑twister that’s been chucking its way ...
# Response 12: The sentence you’re asking about is a classic English tongue...
# Response 5: **Answer:**
# The classic rhyme, best remembered as a tongue...
# Response 16: **A classic answer in the world of chuck‑swinging folklore:*...
# Response 20: I’m sorry if this feels a bit playful, but the classic “how ...
